# %%
import logging

## logging setting

logging.basicConfig(
    level=logging.DEBUG,
    format=' %(name)s  -  %(asctime)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    handlers=[
        logging.FileHandler("appExample1.log"),
        logging.StreamHandler()
    ]
)

logger=logging.getLogger("Arithmethic Application")

def add(a,b):
    result=a+b
    logger.debug(f"Addition {a} + {b}= {result}")
    return result

def subtract(a, b):
    result = a - b
    logger.debug(f"Subtracting {a} - {b} = {result}")
    return result

def multiply(a, b):
    result = a * b
    logger.debug(f"Multiplying {a} * {b} = {result}")
    return result

def divide(a, b):
    try:
        result = a / b
        logger.debug(f"Dividing {a} / {b} = {result}")
        return result
    except ZeroDivisionError:
        logger.error("Division by zero error")
        return None

add(10,15)
subtract(15,10)
multiply(10,20)
divide(20,0)
# Out:
#  Arithmethic Application  -  2025-02-10 12:41:37 - DEBUG - Addition 10 + 15= 25
#  Arithmethic Application  -  2025-02-10 12:41:37 - DEBUG - Subtracting 15 - 10 = 5
#  Arithmethic Application  -  2025-02-10 12:41:37 - DEBUG - Multiplying 10 * 20 = 200
#  Arithmethic Application  -  2025-02-10 12:41:37 - ERROR - Division by zero error
