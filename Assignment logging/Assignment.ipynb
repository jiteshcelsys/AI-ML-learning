# %% [markdown]
# # 1. Basic Logging
# write a function to create a basic logger that logs messages to file named app.log

# %%
# answer
import logging
def basic_logger():
    logging.basicConfig(filename='app.log', level=logging.DEBUG)
    logging.debug('This is a debug message')
    logging.info('This is an info message')
    logging.warning('This is a warning message')
    logging.error('This is an error message')
    logging.critical('This is a critical message')

#Test the function
basic_logger()

# %% [markdown]
# # Logging levels in order of severity: DEBUG < INFO < WARNING < ERROR < CRITICAL.

# %%
logging.basicConfig(level=logging.DEBUG)
logging.debug('This is a debug message')
logging.info('This is an info message')
logging.error('This is an error message')
logging.warning('This is a warning message')
logging.critical('This is a critical message')

# %% [markdown]
# # 2. Logging with different Handlers

# %%
logging.basicConfig(
    level=logging.DEBUG,
    format='%(name)s - %(asctime)s- %(levelname)s- %(message)s',
    datefmt= '%d-%m-%Y %H:%M:%S',
    handlers=[
        logging.FileHandler('app_assign.log'),
        logging.StreamHandler()
    ]
)

# %%
logger = logging.getLogger('Mathematic Operation')
def add(a, b):
    result = a+b
    if(a==1):
        logger.info(' exception when a is less than 0')
        return
    if(a==0 and b==0):
        logger.error(f'addition cannot be possible a, b should be greate than 0')
        return
    if(b>10):
        logger.critical('addtion at critical level when b is greater than 10 ={result}')
        return
    logger.debug(f'addtion{a} + {b} = {result}')
add(1,11)
# Out:
# Mathematic Operation - 10-02-2025 14:46:38- INFO-  exception when a is less than 0

# %% [markdown]
# # 3. Formatting log messages.
